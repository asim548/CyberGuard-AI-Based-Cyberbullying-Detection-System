# %% [markdown]
# # CyberGuard – Week 3 & 4: Evaluation & Demo
#
# Test predictions and launch the Streamlit app.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

from src.predict import predict_text
from src.utils import load_metrics

# %%
samples = [
    'Had a wonderful day with friends at school!',
    'You are so stupid and annoying, go away.',
    'I will hurt you if I see you tomorrow.',
]

for s in samples:
    r = predict_text(s)
    print(f'\nText: {s}')
    print(f'Prediction: {r["label"]} ({r["confidence"]*100:.1f}%)')
    print(f'Probabilities: {r["probabilities"]}')

# %%
import json
metrics = load_metrics()
if metrics:
    print(json.dumps(metrics['test'], indent=2))

# %% [markdown]
# ## Launch Streamlit App
#
# Run in terminal from project root:
#
# ```bash
# streamlit run app.py
# ```
