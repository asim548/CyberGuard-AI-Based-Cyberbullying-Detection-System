# %% [markdown]
# # CyberGuard – Week 2: Model Training
#
# Train TF-IDF + Logistic Regression to classify text into **Safe**, **Toxic**, and **Severe Bullying**.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

from src.train import train_model
from config import MODEL_BUNDLE

# %%
metrics = train_model()
print('Model saved to:', MODEL_BUNDLE)

# %%
print('Test Accuracy:', metrics['test']['accuracy'])
print('Test F1 (macro):', metrics['test']['f1_macro'])
